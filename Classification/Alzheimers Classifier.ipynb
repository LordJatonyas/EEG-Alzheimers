# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# /Users/johnlcj/Documents/Projects/EEG-Alzheimers/Classification/Alzheimers Classifier.ipynb Cell 1 line 1
# ----> <a href='vscode-notebook-cell:/Users/johnlcj/Documents/Projects/EEG-Alzheimers/Classification/Alzheimers%20Classifier.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/Users/johnlcj/Documents/Projects/EEG-Alzheimers/Classification/Alzheimers%20Classifier.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/johnlcj/Documents/Projects/EEG-Alzheimers/Classification/Alzheimers%20Classifier.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.model_selection import train_test_split
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/__init__.py:46
#      43 # let init-time option registration happen
#      44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#      49     Int8Dtype,
#      50     Int16Dtype,
#      51     Int32Dtype,
#      52     Int64Dtype,
#      53     UInt8Dtype,
#      54     UInt16Dtype,
#      55     UInt32Dtype,
#      56     UInt64Dtype,
#      57     Float32Dtype,
#      58     Float64Dtype,
#      59     CategoricalDtype,
#      60     PeriodDtype,
#      61     IntervalDtype,
#      62     DatetimeTZDtype,
#      63     StringDtype,
#      64     BooleanDtype,
#      65     # missing
#      66     NA,
#      67     isna,
#      68     isnull,
#      69     notna,
#      70     notnull,
#      71     # indexes
#      72     Index,
#      73     CategoricalIndex,
#      74     RangeIndex,
#      75     MultiIndex,
#      76     IntervalIndex,
#      77     TimedeltaIndex,
#      78     DatetimeIndex,
#      79     PeriodIndex,
#      80     IndexSlice,
#      81     # tseries
#      82     NaT,
#      83     Period,
#      84     period_range,
#      85     Timedelta,
#      86     timedelta_range,
#      87     Timestamp,
#      88     date_range,
#      89     bdate_range,
#      90     Interval,
#      91     interval_range,
#      92     DateOffset,
#      93     # conversion
#      94     to_numeric,
#      95     to_datetime,
#      96     to_timedelta,
#      97     # misc
#      98     Flags,
#      99     Grouper,
#     100     factorize,
#     101     unique,
#     102     value_counts,
#     103     NamedAgg,
#     104     array,
#     105     Categorical,
#     106     set_eng_float_format,
#     107     Series,
#     108     DataFrame,
#     109 )
#     111 from pandas.core.dtypes.dtypes import SparseDtype
#     113 from pandas.tseries.api import infer_freq
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/api.py:47
#      45 from pandas.core.construction import array
#      46 from pandas.core.flags import Flags
# ---> 47 from pandas.core.groupby import (
#      48     Grouper,
#      49     NamedAgg,
#      50 )
#      51 from pandas.core.indexes.api import (
#      52     CategoricalIndex,
#      53     DatetimeIndex,
#    (...)
#      59     TimedeltaIndex,
#      60 )
#      61 from pandas.core.indexes.datetimes import (
#      62     bdate_range,
#      63     date_range,
#      64 )
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/groupby/__init__.py:1
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:67
#      59 from pandas.core.apply import (
#      60     GroupByApply,
#      61     maybe_mangle_lambdas,
#    (...)
#      64     warn_alias_replacement,
#      65 )
#      66 import pandas.core.common as com
# ---> 67 from pandas.core.frame import DataFrame
#      68 from pandas.core.groupby import (
#      69     base,
#      70     ops,
#      71 )
#      72 from pandas.core.groupby.groupby import (
#      73     GroupBy,
#      74     GroupByPlot,
#    (...)
#      78     _transform_template,
#      79 )
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/frame.py:142
#     135 from pandas.core.arrays.sparse import SparseFrameAccessor
#     136 from pandas.core.construction import (
#     137     ensure_wrapped_if_datetimelike,
#     138     extract_array,
#     139     sanitize_array,
#     140     sanitize_masked_array,
#     141 )
# --> 142 from pandas.core.generic import (
#     143     NDFrame,
#     144     make_doc,
#     145 )
#     146 from pandas.core.indexers import check_key_length
#     147 from pandas.core.indexes.api import (
#     148     DatetimeIndex,
#     149     Index,
#    (...)
#     153     ensure_index_from_sequences,
#     154 )
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/generic.py:146
#     137 from pandas.core.dtypes.inference import (
#     138     is_hashable,
#     139     is_nested_list_like,
#     140 )
#     141 from pandas.core.dtypes.missing import (
#     142     isna,
#     143     notna,
#     144 )
# --> 146 from pandas.core import (
#     147     algorithms as algos,
#     148     arraylike,
#     149     common,
#     150     indexing,
#     151     missing,
#     152     nanops,
#     153     sample,
#     154 )
#     155 from pandas.core.array_algos.replace import should_use_regex
#     156 from pandas.core.arrays import ExtensionArray
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/indexing.py:70
#      60 from pandas.core.construction import (
#      61     array as pd_array,
#      62     extract_array,
#      63 )
#      64 from pandas.core.indexers import (
#      65     check_array_indexer,
#      66     is_list_like_indexer,
#      67     is_scalar_indexer,
#      68     length_of_indexer,
#      69 )
# ---> 70 from pandas.core.indexes.api import (
#      71     Index,
#      72     MultiIndex,
#      73 )
#      75 if TYPE_CHECKING:
#      76     from collections.abc import (
#      77         Hashable,
#      78         Sequence,
#      79     )
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/indexes/api.py:20
#      17 from pandas.core.dtypes.cast import find_common_type
#      19 from pandas.core.algorithms import safe_sort
# ---> 20 from pandas.core.indexes.base import (
#      21     Index,
#      22     _new_Index,
#      23     ensure_index,
#      24     ensure_index_from_sequences,
#      25     get_unanimous_names,
#      26 )
#      27 from pandas.core.indexes.category import CategoricalIndex
#      28 from pandas.core.indexes.datetimes import DatetimeIndex
#
# File ~/Documents/Projects/EEG-Alzheimers/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:28
#      21 import numpy as np
#      23 from pandas._config import (
#      24     get_option,
#      25     using_copy_on_write,
#      26 )
# ---> 28 from pandas._libs import (
#      29     NaT,
#      30     algos as libalgos,
#      31     index as libindex,
#      32     lib,
#      33 )
#      34 from pandas._libs.internals import BlockValuesRefs
#      35 import pandas._libs.join as libjoin
#
# File index.pyx:33, in init pandas._libs.index()
#
# File <frozen importlib._bootstrap>:1064, in _handle_fromlist(module, fromlist, import_, recursive)
#
# SystemError: <built-in function isinstance> returned a result with an exception set

# %%
dataset = np.loadtxt(raw_data, delimiter=" ")

# %%
clf = LogisticRegression(random_state=0).fit(X, y)
